# %%
# This allows matplotlib plots to be shown inline
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math

# Use the Bayesian Methods for Hackers style
plt.style.use('bmh')
matplotlib.rcParams.update({'font.size': 25})
matplotlib.rcParams.update({'legend.fontsize': 15})
matplotlib.rcParams['axes.facecolor'] = 'white'
matplotlib.rcParams['legend.numpoints'] = 1

# %%
# HPS 2015 engineering run reach - 0.5 mm data only
engrun2015 = np.genfromtxt('contours/engineering_run2015_reach.csv', 
                     dtype=[('mass', 'f8'), 
                            ('epsilon', 'f8')],
                     delimiter=',')

#
# Bump hunt projections
#

# HPS 1.1 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
hps_1pt1_bh_proj_pos_l0 = np.genfromtxt('contours/hps_1pt1_4weeks_bh_proj_pos_trig_l0.csv', 
                                 dtype=[('mass', 'f8'), 
                                        ('eps', 'f8')],
                                 delimiter=',')

# HPS 2.2 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
hps_2pt2_bh_proj_pos_l0 = np.genfromtxt('contours/hps_2pt2_4weeks_bh_proj_pos_trig_l0.csv', 
                                 dtype=[('mass', 'f8'), 
                                        ('eps', 'f8')],
                                 delimiter=',')


# HPS 4.4 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
hps_4pt4_bh_proj_pos_l0 = np.genfromtxt('contours/hps_4pt4_4weeks_bh_proj_pos_trig_l0.csv', 
                                 dtype=[('mass', 'f8'), 
                                        ('eps', 'f8')],
                                 delimiter=',')

# HPS 1.1 GeV, 4 weeks bump hunt projection - positron trigger
hps_1pt1_bh_proj_pos = np.genfromtxt('contours/hps_1pt1_4weeks_bh_proj_pos_trig.csv', 
                                 dtype=[('mass', 'f8'), 
                                        ('eps', 'f8')],
                                 delimiter=',')

# HPS 2.2 GeV, 4 weeks bump hunt projection - positron trigger
hps_2pt2_bh_proj_pos = np.genfromtxt('contours/hps_2pt2_4weeks_bh_proj_pos_trig.csv', 
                                 dtype=[('mass', 'f8'), 
                                        ('eps', 'f8')],
                                 delimiter=',')


# HPS 4.4 GeV, 4 weeks bump hunt projection - positron trigger
hps_4pt4_bh_proj_pos = np.genfromtxt('contours/hps_4pt4_4weeks_bh_proj_pos_trig.csv', 
                                 dtype=[('mass', 'f8'), 
                                        ('eps', 'f8')],
                                 delimiter=',')

# HPS 1.1 GeV, 4 weeks bump hunt projection - Nominal
hps_1pt1_bh_proj_nominal = np.genfromtxt('contours/hps_1pt1_4weeks_bh_proj_nominal.csv', 
                                 dtype=[('mass', 'f8'), 
                                        ('eps', 'f8')],
                                 delimiter=',')

# HPS 2.2 GeV, 4 weeks bump hunt projection - Nominal
hps_2pt2_bh_proj_nominal = np.genfromtxt('contours/hps_2pt2_4weeks_bh_proj_nominal.csv', 
                                 dtype=[('mass', 'f8'), 
                                        ('eps', 'f8')],
                                 delimiter=',')


# HPS 4.4 GeV, 4 weeks bump hunt projection - Nominal
hps_4pt4_bh_proj_nominal = np.genfromtxt('contours/hps_4pt4_4weeks_bh_proj_nominal.csv', 
                                 dtype=[('mass', 'f8'), 
                                        ('eps', 'f8')],
                                 delimiter=',')

#
# Vertex
#
                     
# HPS 1.1 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
hps_1pt1_vtx_proj_pos_l0 = np.genfromtxt('contours/hps_1pt1_4weeks_vtx_proj_pos_trig_l0.csv', 
                                  dtype=[('mass', 'f8'), 
                                         ('eps', 'f8')],
                                  delimiter=',')

# HPS 2.2 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
hps_2pt2_vtx_proj_pos_l0 = np.genfromtxt('contours/hps_2pt2_4weeks_vtx_proj_pos_trig_l0.csv', 
                                  dtype=[('mass', 'f8'), 
                                         ('eps', 'f8')],
                                  delimiter=',')


# HPS 4.4 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
hps_4pt4_vtx_proj_pos_l0 = np.genfromtxt('contours/hps_4pt4_4weeks_vtx_proj_pos_trig_l0.csv', 
                                  dtype=[('mass', 'f8'), 
                                         ('eps', 'f8')],
                                  delimiter=',')

# HPS 2.2 GeV, 4 weeks vertex projection - positron trigger
hps_2pt2_vtx_proj_pos = np.genfromtxt('contours/hps_2pt2_4weeks_vtx_proj_pos_trig.csv', 
                                  dtype=[('mass', 'f8'), 
                                         ('eps', 'f8')],
                                  delimiter=',')


# HPS 4.4 GeV, 4 weeks vertex projection - positron trigger
hps_4pt4_vtx_proj_pos = np.genfromtxt('contours/hps_4pt4_4weeks_vtx_proj_pos_trig.csv', 
                                  dtype=[('mass', 'f8'), 
                                         ('eps', 'f8')],
                                  delimiter=',')
                    

# HPS 1.1, 2.2 and 4.4 GeV vertex reach from proposal
hps_2014_vertex = np.genfromtxt('contours/hps_2014_prop_vertex_proj.csv', 
                              dtype=[('mass', 'f8'), 
                                     ('eps', 'f8')],
                              delimiter=',')

# BaBar
babar = np.genfromtxt('contours/babar.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')
# NA48/2
na48 = np.genfromtxt('contours/2015_na482_rescaled_to_95cl.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

# APEX test run
apex_test = np.genfromtxt('contours/apex_test_run.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

# 2014 KLOE
kloe2014 = np.genfromtxt('contours/2014_kloe.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')
# KLOE
kloe = np.genfromtxt('contours/kloe.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')


hades = np.genfromtxt('contours/hades.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

mainz = np.genfromtxt('contours/2014_mainz.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

phenix = np.genfromtxt('contours/2014_phenix.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

amu_2sigma_high = np.genfromtxt('contours/amu_2sigma_high.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

amu_2sigma_low = np.genfromtxt('contours/amu_2sigma_low.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

ae_3sigma = np.genfromtxt('contours/ae_3sigma.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

u70_proj = np.genfromtxt('contours/u70_proj_2sigma.csv', 
                     dtype=[('eps', 'f8'), 
                            ('mass', 'f8')],
                     delimiter=',')

u70 = np.genfromtxt('contours/u70_serpuhov.csv', 
                     dtype=[('eps', 'f8'), 
                            ('mass', 'f8')],
                     delimiter=',')

e774 = np.genfromtxt('contours/e774_andreas_log.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',',)

e137 = np.genfromtxt('contours/e137_andreas_log.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

e141 = np.genfromtxt('contours/e141_andreas_log.csv', 
                     dtype=[('mass', 'f8'), 
                            ('eps', 'f8')],
                     delimiter=',')

# DarkLight projections
dark_light_proj = np.genfromtxt('contours/dark_light.csv', 
                                dtype=[('mass', 'f8'), 
                                ('eps', 'f8')],
                                delimiter=',')
                        

# APEX projections
apex_proj = np.genfromtxt('contours/apex_proj.csv', 
                          dtype=[('mass', 'f8'), 
                                 ('eps', 'f8')],
                          delimiter=',')

# APEX proposal projections
apex_proj_pac37 = np.genfromtxt('contours/apex_proj_pac37.csv', 
                                dtype=[('mass', 'f8'), 
                                       ('eps', 'f8')],
                                delimiter=',')

# %% [markdown]
# # Current Limits

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))

ax.fill_between(amu_2sigma_low['mass'], amu_2sigma_low['eps']*amu_2sigma_low['eps'], 
                amu_2sigma_high['eps']*amu_2sigma_high['eps'], alpha=0.1, color='green')
ax.text(0.009, 0.000003, '$a_{\mu \pm 2 \sigma}$', fontsize=30, color='green', fontweight='bold')

ax.fill_between(ae_3sigma['mass'], ae_3sigma['eps']*ae_3sigma['eps'], 0.001, alpha=0.1, color='red')
ax.text(0.004, 0.0000005, '$a_{e}$', fontsize=30, color='red', fontweight='bold')

# BaBar
ax.fill_between(babar['mass'], babar['eps']*babar['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.3, 0.000002, 'BaBar', fontsize=15, color='0.3', fontweight='bold')

# NA48/2
ax.fill_between(na48['mass'], na48['eps']*na48['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.02, 0.000001, 'NA48/2', fontsize=15, color='0.3', fontweight='bold')

# APEX Test
ax.fill_between(apex_test['mass']/1000, apex_test['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.15, 0.000004, '  APEX\nTest Run', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(kloe2014['mass']/1000, kloe2014['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.6, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(kloe['mass']/1000, kloe['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.1, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(hades['mass'], hades['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.06, 0.000006, 'HADES', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(phenix['mass']/1000, phenix['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.05, 0.000004, 'PHENIX', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(mainz['mass'], mainz['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.09, 0.000003, 'Mainz', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(u70_proj['mass'], u70_proj['eps']*u70_proj['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.003, 0.00000003, 'U70', fontsize=15, color='0.3', fontweight='bold')

#ax.fill_between(u70['mass'], u70['eps']*u70['eps'], 0.001, alpha=0.4, color='blue')

epsilon_squared = np.power(10, e774['eps'])*np.power(10, e774['eps'])
ax.fill_between(np.power(10, e774['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.000001, 'E774', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e137['eps'])*np.power(10, e137['eps'])
ax.fill_between(np.power(10, e137['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.00000002, 'E137', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e141['eps'])*np.power(10, e141['eps'])
ax.fill_between(np.power(10, e141['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.004, 0.0000001, 'E141', fontsize=15, color='0.3', fontweight='bold')

ax.set_xlabel("$A'$ mass (GeV)")
ax.set_ylabel('$\epsilon^2$')
ax.set_ylim(0.00000001, 0.0001)
ax.set_xlim(0.001, 1.2)
ax.set_yscale('log')
ax.set_xscale('log')
ax.legend(loc=3);
# Out:
# /Users/spaul/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# # HPS 2015 Engineering Run

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))

ax.fill_between(amu_2sigma_low['mass'], amu_2sigma_low['eps']*amu_2sigma_low['eps'], 
                amu_2sigma_high['eps']*amu_2sigma_high['eps'], alpha=0.1, color='green')
ax.text(0.009, 0.000003, '$a_{\mu \pm 2 \sigma}$', fontsize=30, color='green', fontweight='bold')

ax.fill_between(ae_3sigma['mass'], ae_3sigma['eps']*ae_3sigma['eps'], 0.001, alpha=0.1, color='red')
ax.text(0.004, 0.0000005, '$a_{e}$', fontsize=30, color='red', fontweight='bold')

# BaBar
ax.fill_between(babar['mass'], babar['eps']*babar['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.3, 0.000002, 'BaBar', fontsize=15, color='0.3', fontweight='bold')

# NA48/2
ax.fill_between(na48['mass'], na48['eps']*na48['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.02, 0.000001, 'NA48/2', fontsize=15, color='0.3', fontweight='bold')

# APEX Test
ax.fill_between(apex_test['mass']/1000, apex_test['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.15, 0.000004, '  APEX\nTest Run', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(kloe2014['mass']/1000, kloe2014['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.6, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(kloe['mass']/1000, kloe['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.1, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(hades['mass'], hades['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.06, 0.000006, 'HADES', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(phenix['mass']/1000, phenix['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.05, 0.000004, 'PHENIX', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(mainz['mass'], mainz['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.09, 0.000003, 'Mainz', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(u70_proj['mass'], u70_proj['eps']*u70_proj['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.003, 0.00000003, 'U70', fontsize=15, color='0.3', fontweight='bold')

#ax.fill_between(u70['mass'], u70['eps']*u70['eps'], 0.001, alpha=0.4, color='blue')

epsilon_squared = np.power(10, e774['eps'])*np.power(10, e774['eps'])
ax.fill_between(np.power(10, e774['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.000001, 'E774', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e137['eps'])*np.power(10, e137['eps'])
ax.fill_between(np.power(10, e137['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.00000002, 'E137', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e141['eps'])*np.power(10, e141['eps'])
ax.fill_between(np.power(10, e141['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.004, 0.0000001, 'E141', fontsize=15, color='0.3', fontweight='bold')

# HPS 2015 engineering run reach - 0.5 mm data only
ax.plot(engrun2015['mass'], engrun2015['epsilon'],
        marker='None', linestyle='-', color='#348ABD',
        label='2015 Engineering Run - 1.7 PAC Days')
ax.fill_between(engrun2015['mass'], engrun2015['epsilon'], 0.001, alpha=0.5, color='#348ABD')
ax.text(0.025, 0.00003, '2015 HPS', fontsize=15, color='blue', fontweight='bold')

ax.set_xlabel("$A'$ mass (GeV)")
ax.set_ylabel('$\epsilon^2$')
ax.set_ylim(0.00000001, 0.0001)
ax.set_xlim(0.001, 1.2)
ax.set_yscale('log')
ax.set_xscale('log')
ax.legend(loc=3);

# %% [markdown]
# # Projections

# %% [markdown]
# ## Nominal

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))

ax.fill_between(amu_2sigma_low['mass'], amu_2sigma_low['eps']*amu_2sigma_low['eps'], 
                amu_2sigma_high['eps']*amu_2sigma_high['eps'], alpha=0.1, color='green')
ax.text(0.009, 0.000003, '$a_{\mu \pm 2 \sigma}$', fontsize=30, color='green', fontweight='bold')

ax.fill_between(ae_3sigma['mass'], ae_3sigma['eps']*ae_3sigma['eps'], 0.001, alpha=0.1, color='red')
ax.text(0.004, 0.0000005, '$a_{e}$', fontsize=30, color='red', fontweight='bold')

# BaBar
ax.fill_between(babar['mass'], babar['eps']*babar['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.3, 0.000002, 'BaBar', fontsize=15, color='0.3', fontweight='bold')

# NA48/2
ax.fill_between(na48['mass'], na48['eps']*na48['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.02, 0.000001, 'NA48/2', fontsize=15, color='0.3', fontweight='bold')

# APEX Test
ax.fill_between(apex_test['mass']/1000, apex_test['eps'], 0.001, alpha=0.4, color='#A60628')
ax.text(0.15, 0.000004, '  APEX\nTest Run', fontsize=15, color='#A60628', fontweight='bold')

ax.fill_between(kloe2014['mass']/1000, kloe2014['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.6, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(kloe['mass']/1000, kloe['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.1, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(hades['mass'], hades['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.06, 0.000006, 'HADES', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(phenix['mass']/1000, phenix['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.05, 0.000004, 'PHENIX', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(mainz['mass'], mainz['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.09, 0.000003, 'Mainz', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(u70_proj['mass'], u70_proj['eps']*u70_proj['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.003, 0.00000003, 'U70', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e774['eps'])*np.power(10, e774['eps'])
ax.fill_between(np.power(10, e774['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.000001, 'E774', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e137['eps'])*np.power(10, e137['eps'])
ax.fill_between(np.power(10, e137['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.00000002, 'E137', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e141['eps'])*np.power(10, e141['eps'])
ax.fill_between(np.power(10, e141['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.004, 0.0000001, 'E141', fontsize=15, color='0.3', fontweight='bold')

# HPS 1.1 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_1pt1_bh_proj_nominal['eps']*hps_1pt1_bh_proj_nominal['eps']
ax.plot(hps_1pt1_bh_proj_nominal['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#009E73', lw=4, label='4 Weeks @ 1.1 GeV')
ax.text(0.055, 0.000001, 'HPS', fontsize=15, color='#009E73', fontweight='bold')

# HPS 2.2 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_2pt2_bh_proj_nominal['eps']*hps_2pt2_bh_proj_nominal['eps']
ax.plot(hps_2pt2_bh_proj_nominal['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#D55E00', lw=4, label='4 Weeks @ 2.2 GeV')
ax.text(0.085, 0.0000004, 'HPS', fontsize=15, color='#D55E00', fontweight='bold')

# HPS 4.4 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_4pt4_bh_proj_nominal['eps']*hps_4pt4_bh_proj_nominal['eps']
ax.plot(hps_4pt4_bh_proj_nominal['mass'], epsilon_squared,
        marker='None', linestyle='-', color='#CC79A7', lw=4, label='4 Weeks @ 4.4 GeV')
ax.text(0.2, 0.0000005, 'HPS', fontsize=15, color='#CC79A7', fontweight='bold')

# HPS 2015 engineering run reach - 0.5 mm data only
ax.plot(engrun2015['mass'], engrun2015['epsilon'],
        marker='None', linestyle='-', color='#348ABD',
        label='2015 Engineering Run - 1.7 PAC Days')
ax.fill_between(engrun2015['mass'], engrun2015['epsilon'], 0.001, alpha=0.5, color='#348ABD')
ax.text(0.025, 0.00003, '2015 HPS', fontsize=15, color='blue', fontweight='bold')

ax.set_xlabel("$A'$ mass (GeV)")
ax.set_ylabel('$\epsilon^2$')
ax.set_ylim(0.00000000001, 0.0001)
ax.set_xlim(0.001, 1.2)
ax.set_yscale('log')
ax.set_xscale('log')
ax.legend(loc=3);

# %% [markdown]
# ## Positron Trigger

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))

ax.fill_between(amu_2sigma_low['mass'], amu_2sigma_low['eps']*amu_2sigma_low['eps'], 
                amu_2sigma_high['eps']*amu_2sigma_high['eps'], alpha=0.1, color='green')
ax.text(0.009, 0.000003, '$a_{\mu \pm 2 \sigma}$', fontsize=30, color='green', fontweight='bold')

ax.fill_between(ae_3sigma['mass'], ae_3sigma['eps']*ae_3sigma['eps'], 0.001, alpha=0.1, color='red')
ax.text(0.004, 0.0000005, '$a_{e}$', fontsize=30, color='red', fontweight='bold')

# BaBar
ax.fill_between(babar['mass'], babar['eps']*babar['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.3, 0.000002, 'BaBar', fontsize=15, color='0.3', fontweight='bold')

# NA48/2
ax.fill_between(na48['mass'], na48['eps']*na48['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.02, 0.000001, 'NA48/2', fontsize=15, color='0.3', fontweight='bold')

# APEX Test
ax.fill_between(apex_test['mass']/1000, apex_test['eps'], 0.001, alpha=0.4, color='#A60628')
ax.text(0.15, 0.000004, '  APEX\nTest Run', fontsize=15, color='#A60628', fontweight='bold')

ax.fill_between(kloe2014['mass']/1000, kloe2014['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.6, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(kloe['mass']/1000, kloe['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.1, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(hades['mass'], hades['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.06, 0.000006, 'HADES', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(phenix['mass']/1000, phenix['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.05, 0.000004, 'PHENIX', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(mainz['mass'], mainz['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.09, 0.000003, 'Mainz', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(u70_proj['mass'], u70_proj['eps']*u70_proj['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.003, 0.00000003, 'U70', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e774['eps'])*np.power(10, e774['eps'])
ax.fill_between(np.power(10, e774['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.000001, 'E774', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e137['eps'])*np.power(10, e137['eps'])
ax.fill_between(np.power(10, e137['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.00000002, 'E137', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e141['eps'])*np.power(10, e141['eps'])
ax.fill_between(np.power(10, e141['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.004, 0.0000001, 'E141', fontsize=15, color='0.3', fontweight='bold')

# HPS 1.1 GeV, 4 weeks bump hunt projection - positron trigger
epsilon_squared = hps_1pt1_bh_proj_pos['eps']*hps_1pt1_bh_proj_pos['eps']
ax.plot(hps_1pt1_bh_proj_pos['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#009E73', lw=4, label='4 Weeks @ 1.1 GeV')
ax.text(0.075, 0.000001, 'HPS', fontsize=15, color='#009E73', fontweight='bold')

# HPS 2.2 GeV, 4 weeks bump hunt projection - positron trigger
epsilon_squared = hps_2pt2_bh_proj_pos['eps']*hps_2pt2_bh_proj_pos['eps']
ax.plot(hps_2pt2_bh_proj_pos['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#D55E00', lw=4, label='4 Weeks @ 2.2 GeV')
ax.text(0.12, 0.0000005, 'HPS', fontsize=15, color='#D55E00', fontweight='bold')

# HPS 4.4 GeV, 4 weeks bump hunt projection - positron trigger
epsilon_squared = hps_4pt4_bh_proj_pos['eps']*hps_4pt4_bh_proj_pos['eps']
ax.plot(hps_4pt4_bh_proj_pos['mass'], epsilon_squared,
        marker='None', linestyle='-', color='#CC79A7', lw=4, label='4 Weeks @ 4.4 GeV')
ax.text(0.25, 0.000001, 'HPS', fontsize=15, color='#CC79A7', fontweight='bold')

# HPS 2.2 GeV, 4 weeks vertex projection - positron trigger
epsilon_squared = hps_2pt2_vtx_proj_pos['eps']*hps_2pt2_vtx_proj_pos['eps']
ax.plot(hps_2pt2_vtx_proj_pos['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#D55E00', lw=4)
ax.text(0.04, 0.000000025, 'HPS', fontsize=15, color='#D55E00', fontweight='bold')

# HPS 4.4 GeV, 4 weeks vertex projection - positron trigger
epsilon_squared = hps_4pt4_vtx_proj_pos['eps']*hps_4pt4_vtx_proj_pos['eps']
ax.plot(hps_4pt4_vtx_proj_pos['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#CC79A7', lw=4)
ax.text(0.1, 0.000000005, 'HPS', fontsize=15, color='#CC79A7', fontweight='bold')

# HPS 2015 engineering run reach - 0.5 mm data only
ax.plot(engrun2015['mass'], engrun2015['epsilon'],
        marker='None', linestyle='-', color='#348ABD',
        label='2015 Engineering Run - 1.7 PAC Days')
ax.fill_between(engrun2015['mass'], engrun2015['epsilon'], 0.001, alpha=0.5, color='#348ABD')
ax.text(0.025, 0.00003, '2015 HPS', fontsize=15, color='blue', fontweight='bold')

ax.set_xlabel("$A'$ mass (GeV)")
ax.set_ylabel('$\epsilon^2$')
ax.set_ylim(0.00000000001, 0.0001)
ax.set_xlim(0.001, 1.2)
ax.set_yscale('log')
ax.set_xscale('log')
ax.legend(loc=3);

# %% [markdown]
# ## Positron Trigger + L0 Upgrades

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))

ax.fill_between(amu_2sigma_low['mass'], amu_2sigma_low['eps']*amu_2sigma_low['eps'], 
                amu_2sigma_high['eps']*amu_2sigma_high['eps'], alpha=0.1, color='green')
ax.text(0.009, 0.000003, '$a_{\mu \pm 2 \sigma}$', fontsize=30, color='green', fontweight='bold')

ax.fill_between(ae_3sigma['mass'], ae_3sigma['eps']*ae_3sigma['eps'], 0.001, alpha=0.1, color='red')
ax.text(0.004, 0.0000005, '$a_{e}$', fontsize=30, color='red', fontweight='bold')

# BaBar
ax.fill_between(babar['mass'], babar['eps']*babar['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.3, 0.000002, 'BaBar', fontsize=15, color='0.3', fontweight='bold')

# NA48/2
ax.fill_between(na48['mass'], na48['eps']*na48['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.02, 0.000001, 'NA48/2', fontsize=15, color='0.3', fontweight='bold')

# APEX Test
ax.fill_between(apex_test['mass']/1000, apex_test['eps'], 0.001, alpha=0.4, color='#A60628')
ax.text(0.15, 0.000004, '  APEX\nTest Run', fontsize=15, color='#A60628', fontweight='bold')

ax.fill_between(kloe2014['mass']/1000, kloe2014['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.6, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(kloe['mass']/1000, kloe['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.1, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(hades['mass'], hades['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.06, 0.000006, 'HADES', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(phenix['mass']/1000, phenix['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.05, 0.000004, 'PHENIX', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(mainz['mass'], mainz['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.09, 0.000003, 'Mainz', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(u70_proj['mass'], u70_proj['eps']*u70_proj['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.003, 0.00000003, 'U70', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e774['eps'])*np.power(10, e774['eps'])
ax.fill_between(np.power(10, e774['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.000001, 'E774', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e137['eps'])*np.power(10, e137['eps'])
ax.fill_between(np.power(10, e137['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.00000002, 'E137', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e141['eps'])*np.power(10, e141['eps'])
ax.fill_between(np.power(10, e141['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.004, 0.0000001, 'E141', fontsize=15, color='0.3', fontweight='bold')

# HPS 1.1 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_1pt1_bh_proj_pos_l0['eps']*hps_1pt1_bh_proj_pos_l0['eps']
ax.plot(hps_1pt1_bh_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#009E73', lw=4, label='4 Weeks @ 1.1 GeV')
ax.text(0.075, 0.000001, 'HPS', fontsize=15, color='#009E73', fontweight='bold')

# HPS 2.2 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_2pt2_bh_proj_pos_l0['eps']*hps_2pt2_bh_proj_pos_l0['eps']
ax.plot(hps_2pt2_bh_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#D55E00', lw=4, label='4 Weeks @ 2.2 GeV')
ax.text(0.12, 0.0000005, 'HPS', fontsize=15, color='#D55E00', fontweight='bold')

# HPS 4.4 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_4pt4_bh_proj_pos_l0['eps']*hps_4pt4_bh_proj_pos_l0['eps']
ax.plot(hps_4pt4_bh_proj_pos_l0['mass'], epsilon_squared,
        marker='None', linestyle='-', color='#CC79A7', lw=4, label='4 Weeks @ 4.4 GeV')
ax.text(0.25, 0.000001, 'HPS', fontsize=15, color='#CC79A7', fontweight='bold')

# HPS 1.1 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
epsilon_squared = hps_1pt1_vtx_proj_pos_l0['eps']*hps_1pt1_vtx_proj_pos_l0['eps']
ax.plot(hps_1pt1_vtx_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#009E73', lw=4)
ax.text(0.025, 0.000000014, 'HPS', fontsize=15, color='#009E73', fontweight='bold')

# HPS 2.2 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
epsilon_squared = hps_2pt2_vtx_proj_pos_l0['eps']*hps_2pt2_vtx_proj_pos_l0['eps']
ax.plot(hps_2pt2_vtx_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#D55E00', lw=4)
ax.text(0.04, 0.000000025, 'HPS', fontsize=15, color='#D55E00', fontweight='bold')

# HPS 4.4 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
epsilon_squared = hps_4pt4_vtx_proj_pos_l0['eps']*hps_4pt4_vtx_proj_pos_l0['eps']
ax.plot(hps_4pt4_vtx_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#CC79A7', lw=4)
ax.text(0.1, 0.000000005, 'HPS', fontsize=15, color='#CC79A7', fontweight='bold')

# HPS 2015 engineering run reach - 0.5 mm data only
ax.plot(engrun2015['mass'], engrun2015['epsilon'],
        marker='None', linestyle='-', color='#348ABD',
        label='2015 Engineering Run - 1.7 PAC Days')
ax.fill_between(engrun2015['mass'], engrun2015['epsilon'], 0.001, alpha=0.5, color='#348ABD')
ax.text(0.025, 0.00003, '2015 HPS', fontsize=15, color='blue', fontweight='bold')

ax.set_xlabel("$A'$ mass (GeV)")
ax.set_ylabel('$\epsilon^2$')
ax.set_ylim(0.00000000001, 0.0001)
ax.set_xlim(0.001, 1.2)
ax.set_yscale('log')
ax.set_xscale('log')
ax.legend(loc=3);

# %% [markdown]
# ## JLab Experiments

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))

ax.fill_between(amu_2sigma_low['mass'], amu_2sigma_low['eps']*amu_2sigma_low['eps'], 
                amu_2sigma_high['eps']*amu_2sigma_high['eps'], alpha=0.1, color='green')
ax.text(0.009, 0.000003, '$a_{\mu \pm 2 \sigma}$', fontsize=30, color='green', fontweight='bold')

ax.fill_between(ae_3sigma['mass'], ae_3sigma['eps']*ae_3sigma['eps'], 0.001, alpha=0.1, color='red')
ax.text(0.004, 0.0000005, '$a_{e}$', fontsize=30, color='red', fontweight='bold')

# BaBar
ax.fill_between(babar['mass'], babar['eps']*babar['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.3, 0.000002, 'BaBar', fontsize=15, color='0.3', fontweight='bold')

# NA48/2
ax.fill_between(na48['mass'], na48['eps']*na48['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.02, 0.000001, 'NA48/2', fontsize=15, color='0.3', fontweight='bold')

# APEX Test
ax.fill_between(apex_test['mass']/1000, apex_test['eps'], 0.001, alpha=0.4, color='#A60628')
ax.text(0.15, 0.000004, '  APEX\nTest Run', fontsize=15, color='#A60628', fontweight='bold')

ax.fill_between(kloe2014['mass']/1000, kloe2014['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.6, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(kloe['mass']/1000, kloe['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.1, 0.00004, 'KLOE', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(hades['mass'], hades['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.06, 0.000006, 'HADES', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(phenix['mass']/1000, phenix['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')
ax.text(0.05, 0.000004, 'PHENIX', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(mainz['mass'], mainz['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.09, 0.000003, 'Mainz', fontsize=15, color='0.3', fontweight='bold')

ax.fill_between(u70_proj['mass'], u70_proj['eps']*u70_proj['eps'], 0.001, alpha=0.4, color='0.5')
ax.text(0.003, 0.00000003, 'U70', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e774['eps'])*np.power(10, e774['eps'])
ax.fill_between(np.power(10, e774['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.000001, 'E774', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e137['eps'])*np.power(10, e137['eps'])
ax.fill_between(np.power(10, e137['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.0015, 0.00000002, 'E137', fontsize=15, color='0.3', fontweight='bold')

epsilon_squared = np.power(10, e141['eps'])*np.power(10, e141['eps'])
ax.fill_between(np.power(10, e141['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')
ax.text(0.004, 0.0000001, 'E141', fontsize=15, color='0.3', fontweight='bold')

# DarkLight
ax.plot(dark_light_proj['mass']/1000, dark_light_proj['eps'],
        marker='None', linestyle='-', lw=4, color='#578fd6')
ax.text(0.015, 0.0000001, 'DarkLight', fontsize=15, color='#578fd6', fontweight='bold')

# APEX
ax.plot(apex_proj_pac37['mass'], apex_proj_pac37['eps']*apex_proj_pac37['eps'],
        marker='None', linestyle='-', lw=4, color='#19d014')
ax.text(0.35, 0.0000001, 'APEX', fontsize=15, color='#19d014', fontweight='bold')

# HPS 1.1 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_1pt1_bh_proj_pos_l0['eps']*hps_1pt1_bh_proj_pos_l0['eps']
ax.plot(hps_1pt1_bh_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='blue', lw=4, label='4 Weeks @ 1.1 GeV')
ax.text(0.075, 0.000001, 'HPS', fontsize=15, color='blue', fontweight='bold')

# HPS 2.2 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_2pt2_bh_proj_pos_l0['eps']*hps_2pt2_bh_proj_pos_l0['eps']
ax.plot(hps_2pt2_bh_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='red', lw=4, label='4 Weeks @ 2.2 GeV')
ax.text(0.12, 0.0000005, 'HPS', fontsize=15, color='red', fontweight='bold')

# HPS 4.4 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_4pt4_bh_proj_pos_l0['eps']*hps_4pt4_bh_proj_pos_l0['eps']
ax.plot(hps_4pt4_bh_proj_pos_l0['mass'], epsilon_squared,
        marker='None', linestyle='-', color='#793da6', lw=4, label='4 Weeks @ 4.4 GeV')
ax.text(0.25, 0.000001, 'HPS', fontsize=15, color='#793da6', fontweight='bold')

# HPS 1.1 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
epsilon_squared = hps_1pt1_vtx_proj_pos_l0['eps']*hps_1pt1_vtx_proj_pos_l0['eps']
ax.plot(hps_1pt1_vtx_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='blue', lw=4)
ax.text(0.025, 0.000000014, 'HPS', fontsize=15, color='blue', fontweight='bold')

# HPS 2.2 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
epsilon_squared = hps_2pt2_vtx_proj_pos_l0['eps']*hps_2pt2_vtx_proj_pos_l0['eps']
ax.plot(hps_2pt2_vtx_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='red', lw=4)
ax.text(0.04, 0.000000025, 'HPS', fontsize=15, color='red', fontweight='bold')

# HPS 4.4 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
epsilon_squared = hps_4pt4_vtx_proj_pos_l0['eps']*hps_4pt4_vtx_proj_pos_l0['eps']
ax.plot(hps_4pt4_vtx_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle='-', color='#793da6', lw=4)
ax.text(0.1, 0.000000005, 'HPS', fontsize=15, color='#793da6', fontweight='bold')

# HPS 2015 engineering run reach - 0.5 mm data only
ax.plot(engrun2015['mass'], engrun2015['epsilon'],
        marker='None', linestyle='-', color='magenta',
        label='2015 Engineering Run - 1.7 PAC Days')
ax.fill_between(engrun2015['mass'], engrun2015['epsilon'], 0.001, alpha=0.1, color='magenta')
ax.text(0.025, 0.00003, '2015 HPS', fontsize=15, color='magenta', fontweight='bold')

ax.set_xlabel("$A'$ mass (GeV)")
ax.set_ylabel('$\epsilon^2$')
ax.set_ylim(0.00000000001, 0.0001)
ax.set_xlim(0.001, 1.2)
ax.set_yscale('log')
ax.set_xscale('log')
# This allows matplotlib plots to be shown inline
# %matplotlib inline

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import math

# Use the Bayesian Methods for Hackers style
plt.style.use('bmh')
matplotlib.rcParams.update({'font.size': 25})
matplotlib.rcParams.update({'legend.fontsize': 15})
matplotlib.rcParams['axes.facecolor'] = 'white'
matplotlib.rcParams['legend.numpoints'] = 1
ax.legend(loc=3);

# %%
engrun2016 = np.genfromtxt('contours/engineering_run2016_reach.csv', 
                     dtype=[('mass', 'f8'), 
                            ('epsilon', 'f8')],
                     delimiter=',')
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 12))

ax.fill_between(amu_2sigma_low['mass'], amu_2sigma_low['eps']*amu_2sigma_low['eps'], 
                amu_2sigma_high['eps']*amu_2sigma_high['eps'], alpha=0.1, color='green')

ax.fill_between(ae_3sigma['mass'], ae_3sigma['eps']*ae_3sigma['eps'], 0.001, alpha=0.1, color='red')


# BaBar
ax.fill_between(babar['mass'], babar['eps']*babar['eps'], 0.001, alpha=0.4, color='0.5')

# NA48/2
ax.fill_between(na48['mass'], na48['eps']*na48['eps'], 0.001, alpha=0.4, color='0.5')

# APEX Test
ax.fill_between(apex_test['mass']/1000, apex_test['eps'], 0.001, alpha=0.4, color='0.5')

ax.fill_between(kloe2014['mass']/1000, kloe2014['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')

ax.fill_between(kloe['mass']/1000, kloe['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')

ax.fill_between(hades['mass'], hades['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')

ax.fill_between(phenix['mass']/1000, phenix['eps']*math.sqrt(1.96/1.64), 0.001, alpha=0.4, color='0.5')

ax.fill_between(mainz['mass'], mainz['eps'], 0.001, alpha=0.4, color='0.5')

ax.fill_between(u70_proj['mass'], u70_proj['eps']*u70_proj['eps'], 0.001, alpha=0.4, color='0.5')

epsilon_squared = np.power(10, e774['eps'])*np.power(10, e774['eps'])
ax.fill_between(np.power(10, e774['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')

epsilon_squared = np.power(10, e137['eps'])*np.power(10, e137['eps'])
ax.fill_between(np.power(10, e137['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')

epsilon_squared = np.power(10, e141['eps'])*np.power(10, e141['eps'])
ax.fill_between(np.power(10, e141['mass']), epsilon_squared, 0.001, alpha=0.4, color='0.5')

label_exclusions = True
if label_exclusions:
    grey_label = '#000000'
    a = 0.30
    big = 40
    small = 17
    ax.text(0.006, 0.0000025, '$a_{\mu \pm 2 \sigma}$', fontsize=big, color='green', fontweight='bold')
    ax.text(0.004, 0.0000005, '$a_{e}$', fontsize=big, color='#FF4444', fontweight='bold')
    ax.text(0.3, 0.000002, 'BaBar', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.02, 0.000001, 'NA48/2', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.15, 0.000004, '  APEX', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.6, 0.00004, 'KLOE', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.1, 0.00004, 'KLOE', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.06, 0.000007, 'HADES', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.05, 0.000004, 'PHENIX', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.09, 0.0000025, 'Mainz', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.003, 0.00000003, 'U70', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.0015, 0.000001, 'E774', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.0015, 0.00000002, 'E137', fontsize=small, color=grey_label, alpha=a, fontweight='bold')
    ax.text(0.004, 0.0000001, 'E141', fontsize=small, color=grey_label, alpha=a, fontweight='bold')

# HPS 2015 engineering run reach - 0.5 mm data only
ax.plot(engrun2015['mass'], engrun2015['epsilon'],
        marker='None', linestyle='-', color='#FF0000',
        label='2015 data @ 1.1 GeV')


# HPS 1.1 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_1pt1_bh_proj_nominal['eps']*hps_1pt1_bh_proj_nominal['eps']
ax.plot(hps_1pt1_bh_proj_nominal['mass'], epsilon_squared, 
        marker='None', linestyle=':', color='#FF0000', lw=4, label='   4 weeks @ 1.1 GeV')

# HPS 2016 engineering run reach
ax.plot(engrun2016['mass'], engrun2016['epsilon'],
        marker='None', linestyle='-', color='#0000FF',
        label='2016 data @ 2.2 GeV')

# HPS 2.2 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_2pt2_bh_proj_nominal['eps']*hps_2pt2_bh_proj_nominal['eps']
ax.plot(hps_2pt2_bh_proj_nominal['mass'], epsilon_squared, 
        marker='None', linestyle=':', color='#0000FF', lw=4, label='   4 weeks @ 2.2 GeV')

# HPS 4.4 GeV, 4 weeks bump hunt projection - positron trigger + L0 upgrades
epsilon_squared = hps_4pt4_bh_proj_nominal['eps']*hps_4pt4_bh_proj_nominal['eps']
ax.plot(hps_4pt4_bh_proj_nominal['mass'], epsilon_squared,
        marker='None', linestyle=':', color='#FF8800', lw=4, label='   4 weeks @ 4.4 GeV')

# HPS 1.1 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
epsilon_squared = hps_1pt1_vtx_proj_pos_l0['eps']*hps_1pt1_vtx_proj_pos_l0['eps']
ax.plot(hps_1pt1_vtx_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle=':', color='#FF0000', lw=4)

# HPS 2.2 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
epsilon_squared = hps_2pt2_vtx_proj_pos_l0['eps']*hps_2pt2_vtx_proj_pos_l0['eps']
ax.plot(hps_2pt2_vtx_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle=':', color='#0000FF', lw=4)

# HPS 4.4 GeV, 4 weeks vertex projection - positron trigger + L0 upgrades
epsilon_squared = hps_4pt4_vtx_proj_pos_l0['eps']*hps_4pt4_vtx_proj_pos_l0['eps']
ax.plot(hps_4pt4_vtx_proj_pos_l0['mass'], epsilon_squared, 
        marker='None', linestyle=':', color='#FF8800', lw=4)




ax.set_xlabel("$A'$ mass (GeV)", fontsize=40)
ax.set_ylabel('$\epsilon^2$', fontsize=40)
ax.set_ylim(0.00000000001, 0.0001)
ax.set_xlim(0.001, 1.2)
ax.set_yscale('log')
ax.set_xscale('log')

ax.yaxis.set_label_coords(-0.05,0.5)
ax.legend(loc=3, prop={'size': 25});

fig.savefig('reach_new.pdf')
